# %%
pip install langchain-groq
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(
    temperature=0, 
    groq_api_key='enter api key', 
    model_name="llama-3.1-70b-versatile"
)

response = llm.invoke("The first person to land on moon was ...")
print(response.content)
# Out:
# The first person to land on the moon was Neil Armstrong. He stepped onto the lunar surface on July 20, 1969, as part of the Apollo 11 mission.

# %%
# Install the required packages
# %pip install langchain-community
# %pip install beautifulsoup4

from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://www.google.com/about/careers/applications/jobs/results/121209170417328838-software-student-training-in-engineering-program-step-intern-2025-english")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# Experienced Software Engineer Hiring
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# We no longer support this browser.  Using a supported browser will provide a better experience.
# Please update your browser.
#
#
#
# Close browser message
#
#
#
#
#
#
#
# Skip to Main Content
#
#
#
#
#
#
#
#
#
# Open Navigation
#
#
#
#
#
#
#
#
# Students programs
#
#
#
#
#
#
# Work with us
#
#
#
#
#
#
# Grow with us
#
#
#
#
#
#
# How we hire
#
#
#
#
#
#
# Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Submit to search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
res.content
# Out:
# '[\n  {\n    "role": "Experienced Software Engineer",\n    "experience": "Previous software engineering work experience",\n    "skills": [\n      "Hands-on experience in system design, application development, testing and operational stability",\n      "Proficiency in Java or Python",\n      "Familiarity with the Software Development Lifecycle and Agile methodologies",\n      "Exceptional problem solving and analytical thinking skills"\n    ],\n    "description": "We are hiring for opportunities in multiple locations worldwide, and will expand to more of our technology centers soon! After passing an online skills-based coding assessment and successfully completing assessments of technical proficiency and behaviors, you’ll meet teams across our technology space with different projects and areas of business focus. From there, we will work with you to understand your job preferences and help you find the role that fits you best based on your skills, proficiencies and behaviors."\n  }\n]
# ...

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# [{'role': 'Experienced Software Engineer',
#   'experience': 'Previous software engineering work experience',
#   'skills': ['Hands-on experience in system design, application development, testing and operational stability',
#    'Proficiency in Java or Python',
#    'Familiarity with the Software Development Lifecycle and Agile methodologies',
#    'Exceptional problem solving and analytical thinking skills'],
#   'description': 'We are hiring for opportunities in multiple locations worldwide, and will expand to more of our technology centers soon! After passing an online skills-based coding assessment and successfully completing assessments of technical proficiency and behaviors, you’ll meet teams across our technology space with different projects and areas of business focus. From there, we will work with you to understand your job preferences and help you find the role that fits you best based on your skills, proficiencies and behaviors.'}]

# %%
for job in json_res:
    print(job['skills'])
    #for skill in job['skills']:
       # print(skill)
# Out:
# ['Hands-on experience in system design, application development, testing and operational stability', 'Proficiency in Java or Python', 'Familiarity with the Software Development Lifecycle and Agile methodologies', 'Exceptional problem solving and analytical thinking skills']

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])

# %%
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/java-portfolio'},
#   {'links': 'https://example.com/android-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/python-portfolio'}],
#  [{'links': 'https://example.com/kotlin-backend-portfolio'},
#   {'links': 'https://example.com/java-portfolio'}],
#  [{'links': 'https://example.com/angular-portfolio'},
#   {'links': 'https://example.com/full-stack-js-portfolio'}]]

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Arshia, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Arshia, BDE at AtliQ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Expert Software Engineering Solutions for Your Business Needs
#
# Dear Hiring Manager,
#
# I came across your job posting for an Experienced Software Engineer and was impressed by the scope of your project. As a Business Development Executive at AtliQ, I'd like to introduce you to our company's capabilities in delivering top-notch software engineering solutions that align with your requirements.
#
# At AtliQ, we specialize in providing AI-powered and software consulting services that cater to the unique needs of businesses like yours. Our team of expert software engineers has hands-on experience in system design, application development, testing, and operational stability. We're proficient in languages like Java and Python, and our familiarity with the Software Development Lifecycle and Agile methodologies ensures seamless project execution.
#
# Our portfolio showcases our expertise in various technologies, including:
#
# * Java: https://example.com/java-portfolio
# ...
